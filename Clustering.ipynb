# %%
import pandas as pd
import numpy as np
from scipy.cluster.vq import kmeans, vq
import seaborn as sns
from scipy.cluster.vq import whiten
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('wine-clustering.csv',header = 'infer')

# %%
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
df1 = pd.DataFrame(StandardScaler().fit_transform(df),columns = df.columns)

# %%
df1
# Out:
#       Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    1.518613   -0.562250  0.232053     -1.169593   1.913905       0.808997
# 1    0.246290   -0.499413 -0.827996     -2.490847   0.018145       0.568648
# 2    0.196879    0.021231  1.109334     -0.268738   0.088358       0.808997
# 3    1.691550   -0.346811  0.487926     -0.809251   0.930918       2.491446
# 4    0.295700    0.227694  1.840403      0.451946   1.281985       0.808997
# ..        ...         ...       ...           ...        ...            ...
# 173  0.876275    2.974543  0.305159      0.301803  -0.332922      -0.985614
# 174  0.493343    1.412609  0.414820      1.052516   0.158572      -0.793334
# 175  0.332758    1.744744 -0.389355      0.151661   1.422412      -1.129824
# 176  0.209232    0.227694  0.012732      0.151661   1.422412      -1.033684
# 177  1.395086    1.583165  1.365208      1.502943  -0.262708      -0.392751
#
# ...

# %%
df1.dtypes
# Out:
# Alcohol                 float64
# Malic_Acid              float64
# Ash                     float64
# Ash_Alcanity            float64
# Magnesium               float64
# Total_Phenols           float64
# Flavanoids              float64
# Nonflavanoid_Phenols    float64
# Proanthocyanins         float64
# Color_Intensity         float64
# Hue                     float64
# OD280                   float64
# Proline                 float64
# dtype: object

# %%
df1.describe()
# Out:
#             Alcohol    Malic_Acid           Ash  Ash_Alcanity     Magnesium  \
# count  1.780000e+02  1.780000e+02  1.780000e+02  1.780000e+02  1.780000e+02
# mean  -8.619821e-16 -8.357859e-17 -8.657245e-16 -1.160121e-16 -1.995907e-17
# std    1.002821e+00  1.002821e+00  1.002821e+00  1.002821e+00  1.002821e+00
# min   -2.434235e+00 -1.432983e+00 -3.679162e+00 -2.671018e+00 -2.088255e+00
# 25%   -7.882448e-01 -6.587486e-01 -5.721225e-01 -6.891372e-01 -8.244151e-01
# 50%    6.099988e-02 -4.231120e-01 -2.382132e-02  1.518295e-03 -1.222817e-01
# 75%    8.361286e-01  6.697929e-01  6.981085e-01  6.020883e-01  5.096384e-01
# max    2.259772e+00  3.109192e+00  3.156325e+00  3.154511e+00  4.371372e+00
#
#        Total_Phenols    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count   1.780000e+02  1.780000e+02          1.780000e+02     1.780000e+02
# mean   -2.972030e-16 -4.016762e-16          4.079134e-16    -1.699639e-16
# ...

# %%
a = list(df1.columns)
a
# Out:
# ['Alcohol',
#  'Malic_Acid',
#  'Ash',
#  'Ash_Alcanity',
#  'Magnesium',
#  'Total_Phenols',
#  'Flavanoids',
#  'Nonflavanoid_Phenols',
#  'Proanthocyanins',
#  'Color_Intensity',
#  'Hue',
#  'OD280',
#  'Proline',
#  'cluster_labels']

# %%
df1.isna().count()
# Out:
# Alcohol                 178
# Malic_Acid              178
# Ash                     178
# Ash_Alcanity            178
# Magnesium               178
# Total_Phenols           178
# Flavanoids              178
# Nonflavanoid_Phenols    178
# Proanthocyanins         178
# Color_Intensity         178
# Hue                     178
# OD280                   178
# Proline                 178
# dtype: int64

# %%
distortions = []
num_clusters = range(1, 7)

# %%
for i  in num_clusters:
   cluster_centers, distortion = kmeans(df1[a],i)
   distortions.append(distortion)

# %%
elbow_plot = pd.DataFrame({'num_clusters': num_clusters, 'distortions': distortions})

# %%
sns.lineplot(x='num_clusters', y='distortions', data = elbow_plot)
plt.xticks(num_clusters)
plt.show()

# %%
cluster_centers, distortion = kmeans(df1[a],3)

# %%
df1['cluster_labels'],distortion_list = vq(df1[a],cluster_centers)

# %%
sns.scatterplot( x = 'Alcohol',y = 'Malic_Acid',hue = 'cluster_labels',data = df1)
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='Malic_Acid'>

# %%
km = KMeans(n_clusters = 3)

# %%
df_new = df1[['Alcohol','Malic_Acid']]
km.fit(df_new)
# Out:
# KMeans(n_clusters=3)

# %%
df_new['labels'] = km.labels_
# Out:
# C:\Users\ALI~1.AMM\AppData\Local\Temp/ipykernel_2012/163773978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['labels'] = km.labels_

# %%
sns.scatterplot(
    x = df_new["Alcohol"],
    y = df_new["Malic_Acid"],
    hue = df_new["labels"],
    style = km.labels_,
    palette = ["red", "green", "blue"])
plt.scatter(
    km.cluster_centers_[:,0],
    km.cluster_centers_[:,1],
    marker = "x",
    s = 200,
    c = "yellow")
